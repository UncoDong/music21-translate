# %% [markdown]
# ### 开始music21
# 首先验证一下是否进行工作

# %%
from music21 import *

# %% [markdown]
# 如果上述引入没有问题的话，那么通过下面的命令测试是否可以访问Music21自带的库

# %%
s = corpus.parse('bach/bwv65.2.xml')

# %% [markdown]
# 现在s代表JS Bach合唱的整个乐谱。键入`s.analyze('key')`以查看music21对其键的最佳猜测是：

# %%
s.analyze('key')
# Out:
# <music21.key.Key of a minor>

# %% [markdown]
# 现在，让我们看看是否可以使用来查看得分music21。如果这样做不起作用，则可以跳到 第8章：安装MusicXML阅读器， 或者仅完成本教程，直到到达那里而看不到乐谱。输入` s.show()`。假设您的安装和配置按预期进行，MusicXML阅读器应启动并显示合唱效果，看起来类似于我们在此处看到的内容：

# %%
fp = s.write('midi',fp = 'C:\\Users\\UncleDong\\Desktop\\music21_learn\\blah.mid')

# %%
s.show()

# %%
c = chord.Chord("C4 E4 G4")
c.isConsonant()
# Out:
# True

# %%
env = environment.Environment()
print('Environment settings:')
env['lilypondPath']='D:\\Program Files (x86)\\LilyPond\\usr\\bin'
print('musicXML:  ', env['musicxmlPath'])
print('musescore: ', env['musescoreDirectPNGPath'])
print('lilypond:  ', env['lilypondPath'])
# Out:
# Environment settings:
# musicXML:   D:\Program Files\MuseScore 3\bin\MuseScore3.exe
# musescore:  D:\Program Files\MuseScore 3\bin\MuseScore3.exe
# lilypond:   D:\Program Files (x86)\LilyPond\usr\bin

# %%
s.show('midi')
# Out:
#                 <div id='midiPlayerDiv4793'></div>
#                 <link rel="stylesheet" href="//cuthbertLab.github.io/music21j/css/m21.css"
#                     type="text/css" />
#                 <script>
#                 require.config({
#                     paths: {'music21': '//cuthbertLab.github.io/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer('#midiPlayerDiv4793');
#                                mp.base64Load('data:audio/midi;base64,...');
#                         });
#                 </script>
